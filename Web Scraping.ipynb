# %%
+pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda2\lib\site-packages)
# WARNING: Ignoring invalid distribution -blib (c:\programdata\anaconda2\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda2\lib\site-packages)
# WARNING: Ignoring invalid distribution -oblib (c:\programdata\anaconda2\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda2\lib\site-packages)
# WARNING: Ignoring invalid distribution -ilelock (c:\programdata\anaconda2\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda2\lib\site-packages)
# WARNING: Ignoring invalid distribution -blib (c:\programdata\anaconda2\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\programdata\anaconda2\lib\site-packages)
# WARNING: Ignoring invalid distribution -blib (c:\programdata\anaconda2\lib\site-packages)
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.flipkart.com/"
r = requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
url = "https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo,ash,ank,edy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts"
r = requests.get(url)
print(r)

soup = BeautifulSoup(r.text, "lxml")
print(soup)                       # HTML data of this site
# Out:
# <Response [200]>
# <!DOCTYPE html>
# ...

# %%
url = "https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo,ash,ank,edy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts"
r = requests.get(url)
print(r)

soup = BeautifulSoup(r.text, "lxml")

np = soup.find("a",class_ = "_1LKTO3").get("href")  # np - next_page_link

cnp = "https://www.flipkart.com" + np      # cnp - complete_next_page_link
print(cnp)
# Out:
# <Response [200]>
# https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo%2Cash%2Cank%2Cedy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts&page=2

# %%
# for all pages links by using for loop

for i in range(2,26):
    url = "https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo%2Cash%2Cank%2Cedy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts&page="+str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    np = soup.find("a",class_ = "_1LKTO3").get("href")
    cnp = "https://www.flipkart.com"+np
    print(cnp)
# Out:
# https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo%2Cash%2Cank%2Cedy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts&page=1
# https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo%2Cash%2Cank%2Cedy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts&page=2
# https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo%2Cash%2Cank%2Cedy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts&page=3
# https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo%2Cash%2Cank%2Cedy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts&page=4
# https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo%2Cash%2Cank%2Cedy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts&page=5
# ...

# %%
# find the one page data 
Product_Name = []
Brand_name=[]
Prices=[]
Original_Price=[]
Offer=[]
Size=[]
Description=[]


url = "https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo%2Cash%2Cank%2Cedy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts&page="+str(1)
r = requests.get(url)
soup = BeautifulSoup(r.text, "lxml")
names = soup.find_all("a",class_="IRpwTa")
# print(names)

 # only shart name find Then
for i in names:
    name=i.text
    Product_Name.append(name)
print(Product_Name)
# Out:
# ['Men Graphic Print Round Neck Cotton Blend Black T-Shirt', 'Oversize Men Tie & Dye Round Neck Pure Cotton Multicolo...', 'Men Checkered Round Neck Polyester Grey T-Shirt', 'Pack of 4 Men Solid Round Neck Polyester Silver, Blue, ...', 'Men Printed Hooded Neck Cotton Blend White T-Shirt', 'Men Solid Round Neck Cotton Blend Black T-Shirt', 'Men Printed Round Neck Pure Cotton Grey T-Shirt', 'Ms Ess Men Solid Polo Neck Pure Cotton White T-Shirt', 'Men Graphic Print Round Neck Pure Cotton Brown T-Shirt', 'Men Self Design Polo Neck Cotton Blend (220 gsm) Green ...', 'Men Printed Round Neck Pure Cotton White T-Shirt', 'SWAGGERjns Printed Men Hooded Neck T-Shirt Men Self Des...', 'Men Printed Round Neck Cotton Blend Black T-Shirt', 'Men Printed Round Neck Cotton Blend Light Blue T-Shirt', 'Men Printed, Typography Round Neck Pure Cotton Grey T-S...', 'Men Colorblock Hooded Neck Cotton Blend Black, Red T-Sh...', 'Men Solid Mandarin Collar Pure Cotton Green T-Shirt', 'Pack of 2 Men Self Design 
# ...

# %% [markdown]
# # For Singal Web Pages

# %%
Prices = []
prices = soup.find_all("div",class_="_30jeq3")
#print(prices)

 # only shart prices find Then
for i in prices:
    name=i.text
    Prices.append(name)
print(Prices)
# Out:
# ['₹319', '₹399', '₹279', '₹439', '₹299', '₹249', '₹284', '₹759', '₹699', '₹299', '₹450', '₹339', '₹199', '₹239', '₹1,049', '₹199', '₹344', '₹499', '₹299', '₹237', '₹415', '₹399', '₹279', '₹239', '₹299', '₹379', '₹584', '₹499', '₹149', '₹237', '₹399', '₹469', '₹279', '₹279', '₹244', '₹237', '₹775', '₹469', '₹239', '₹279', '₹584', '₹319', '₹199', '₹299', '₹759']

# %%
OriginalPrice=[]

price = soup.find_all("div",class_="_3I9_wc")
#print(prices)

 # only shart Org_Price find Then
for i in price:
    name=i.text
    Original_Price.append(name)
print(Original_Price)
# Out:
# ['₹1,999', '₹1,199', '₹999', '₹1,499', '₹1,499', '₹1,299', '₹1,199', '₹1,699', '₹1,699', '₹999', '₹1,799', '₹1,099', '₹666', '₹666', '₹1,999', '₹999', '₹1,099', '₹2,598', '₹999', '₹799', '₹1,599', '₹1,199', '₹999', '₹666', '₹1,519', '₹1,100', '₹999', '₹1,499', '₹1,499', '₹799', '₹1,199', '₹1,499', '₹999', '₹999', '₹2,099', '₹799', '₹799', '₹1,499', '₹666', '₹999']

# %%
Brand_Name=[]

Brd_name = soup.find_all("div",class_="_2WkVRV")
#print(prices)

 # only shart Org_Price find Then
for i in Brd_name:
    name=i.text
    Brand_Name.append(name)
print(Brand_Name)
# Out:
# ['BLIVE', 'Veirdo', 'VeBNoR', 'FTX', 'AUSK', 'London Hills', 'JOZMER', 'PUMA', 'BEWAKOOF', '3BROS', 'Mr Bowerbird', 'SWAGGERjns', 'NB NICKY BOY', 'NB NICKY BOY', 'BEWAKOOF', 'HELMONT', 'Urbano Fashion', 'London Hills', '3BROS', 'Coolwiz', 'Roadster', 'Veirdo', 'VeBNoR', 'NB NICKY BOY', 'Jump Cuts', 'NB NICKY BOY', 'ADIDAS', 'COUNTRY YARD', 'AUSK', 'Coolwiz', 'Veirdo', 'FTX', 'VeBNoR', 'VeBNoR', 'UrGear', 'Coolwiz', 'Roadster', 'FTX', 'NB NICKY BOY', 'VeBNoR']

# %%
Offer=[]

offers = soup.find_all("div",class_="_3Ay6Sb")
#print(prices)

 # only shart Org_Price find Then
for i in offers:
    name=i.text
    Offer.append(name)
print(Offer)
# Out:
# ['84% off', '66% off', '72% off', '70% off', '80% off', '80% off', '76% off', '55% off', '58% off', '70% off', '74% off', '69% off', '70% off', '64% off', '47% off', '80% off', '68% off', '80% off', '70% off', '70% off', '74% off', '66% off', '72% off', '64% off', '80% off', '65% off', '41% off', '66% off', '90% off', '70% off', '66% off', '68% off', '72% off', '72% off', '88% off', '70% off', '3% off', '68% off', '64% off', '72% off', '41% off', '84% off', '70% off', '80% off', '55% off']

# %% [markdown]
# # For 24 Web Pages

# %%
for i in range(2,26):
    
    url = "https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo%2Cash%2Cank%2Cedy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts&page="+str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    names = soup.find_all("a",class_="IRpwTa")
    # print(names)
    # only shart name find Then
    for i in names:
        name=i.text
        Product_Name.append(name)
    print(Product_Name)
# Out:
# ['Men Graphic Print Round Neck Cotton Blend Black T-Shirt', 'Oversize Men Tie & Dye Round Neck Pure Cotton Multicolo...', 'Men Checkered Round Neck Polyester Grey T-Shirt', 'Pack of 4 Men Solid Round Neck Polyester Silver, Blue, ...', 'Men Printed Hooded Neck Cotton Blend White T-Shirt', 'Men Solid Round Neck Cotton Blend Black T-Shirt', 'Men Printed Round Neck Pure Cotton Grey T-Shirt', 'Ms Ess Men Solid Polo Neck Pure Cotton White T-Shirt', 'Men Graphic Print Round Neck Pure Cotton Brown T-Shirt', 'Men Self Design Polo Neck Cotton Blend (220 gsm) Green ...', 'Men Printed Round Neck Pure Cotton White T-Shirt', 'SWAGGERjns Printed Men Hooded Neck T-Shirt Men Self Des...', 'Men Printed Round Neck Cotton Blend Black T-Shirt', 'Men Printed Round Neck Cotton Blend Light Blue T-Shirt', 'Men Printed, Typography Round Neck Pure Cotton Grey T-S...', 'Men Colorblock Hooded Neck Cotton Blend Black, Red T-Sh...', 'Men Solid Mandarin Collar Pure Cotton Green T-Shirt', 'Pack of 2 Men Self Design 
# ...

# %%
for i in range(2,26):
    
    url = "https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo%2Cash%2Cank%2Cedy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts&page="+str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")   
    Brand_Name=[]
    Brd_name = soup.find_all("div",class_="_2WkVRV")
    #print(prices)
    # only shart Org_Price find Then
    for i in Brd_name:
        name=i.text
        Brand_Name.append(name)
    print(Brand_Name)
# Out:
# ['FTX', 'KYK', 'NB NICKY BOY', 'BLIVE', 'VeBNoR', 'InkTees', 'FTX', 'Veirdo', 'London Hills', 'InkTees', 'KYK', 'Mr Bowerbird', 'AUSK', 'Madfrog', 'EyeBogler', '3BROS', 'PUMA', 'Roadster', 'Smartees', 'NB NICKY BOY', 'Jangoboy', 'London Hills', 'MOONVELLY', 'NB NICKY BOY', 'LEWEL', 'VeBNoR', 'COUNTRY YARD', 'Roadster', 'Smartees', 'LEWEL', 'FTX', 'Crastic', 'EyeBogler', 'Roadster', 'Triptee', 'VeBNoR', 'Veirdo', 'KYK', 'VeBNoR', 'BLIVE']
# ['FTX', 'KYK', 'Reya', 'METRONAUT By Flipkart', 'METRONAUT By Flipkart', 'Allen Solly', 'FTX', 'Veirdo', 'Reya', '3BROS', 'KYK', 'Mr Bowerbird', 'Diversify', 'UrGear', 'LEWEL', 'Plus91', 'PUMA', 'Roadster', 'Jump Cuts', 'TRIPR', 'London Hills', 'Roadster', 'VeBNoR', 'VeBNoR', '3BROS', '3BROS', 'COUNTRY YARD', 'FTX', 'NB NICKY BOY', 'EyeBogler', 'ADIDAS', 'Veirdo', 'NB NICKY BOY', 'AUSK', 'MAYUR CLOTHING', 'TQH', 'Roadster', 'KYK', 'UrGear', 'EyeBogler']
# ...

# %%
for i in range(2,26):
    
    url = "https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo%2Cash%2Cank%2Cedy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts&page="+str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    Prices = []
    prices = soup.find_all("div",class_="_30jeq3")
    #print(prices)
    # only shart prices find Then
    for i in prices:
        name=i.text
        Prices.append(name)
    print(Prices)
# Out:
# ['₹759', '₹584', '₹299', '₹299', '₹249', '₹349', '₹319', '₹399', '₹308', '₹259', '₹1,259', '₹1,735', '₹271', '₹349', '₹249', '₹400', '₹344', '₹1,349', '₹230', '₹400', '₹759', '₹863', '₹239', '₹279', '₹249', '₹239', '₹1,709', '₹859', '₹399', '₹299', '₹599', '₹1,039', '₹259', '₹278', '₹199', '₹299', '₹399', '₹189', '₹299', '₹240', '₹584', '₹319', '₹259', '₹399', '₹249']
# ['₹469', '₹250', '₹261', '₹379', '₹379', '₹494', '₹439', '₹399', '₹265', '₹299', '₹250', '₹249', '₹282', '₹279', '₹299', '₹389', '₹450', '₹759', '₹329', '₹249', '₹476', '₹399', '₹279', '₹349', '₹329', '₹299', '₹499', '₹415', '₹199', '₹199', '₹499', '₹469', '₹379', '₹279', '₹463', '₹329', '₹294', '₹399', '₹278', '₹249', '₹199', '₹250', '₹249', '₹469', '₹759']
# ...

# %%
for i in range(2,26):
    
    url = "https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo%2Cash%2Cank%2Cedy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts&page="+str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    OriginalPrice=[]
    price = soup.find_all("div",class_="_3I9_wc")
    #print(prices)
    # only shart Org_Price find Then
    for i in price:
        name=i.text
        Original_Price.append(name)
    print(Original_Price)
# Out:
# ['₹1,999', '₹1,199', '₹999', '₹1,499', '₹1,499', '₹1,299', '₹1,199', '₹1,699', '₹1,699', '₹999', '₹1,799', '₹1,099', '₹666', '₹666', '₹1,999', '₹999', '₹1,099', '₹2,598', '₹999', '₹799', '₹1,599', '₹1,199', '₹999', '₹666', '₹1,519', '₹1,100', '₹999', '₹1,499', '₹1,499', '₹799', '₹1,199', '₹1,499', '₹999', '₹999', '₹2,099', '₹799', '₹799', '₹1,499', '₹666', '₹999', '₹999', '₹2,495', '₹1,299', '₹499', '₹1,499', '₹999', '₹2,499', '₹999', '₹1,599', '₹666', '₹1,749', '₹777', '₹1,999', '₹999', '₹1,999', '₹2,499', '₹299', '₹1,099', '₹999', '₹999', '₹999', '₹999', '₹999', '₹999', '₹1,999', '₹1,999', '₹666', '₹999', '₹1,999', '₹1,299', '₹999', '₹1,499', '₹1,499', '₹1,099', '₹999', '₹1,999', '₹1,499', '₹1,599', '₹1,599']
# ...

# %%
for i in range(2,26):
    
    url = "https://www.flipkart.com/clothing-and-accessories/topwear/tshirt/men-tshirt/pr?sid=clo%2Cash%2Cank%2Cedy&otracker=categorytree&otracker=nmenu_sub_Men_0_T-Shirts&page="+str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")
    Offer=[]
    offers = soup.find_all("div",class_="_3Ay6Sb")
    #print(prices)
    # only shart Org_Price find Then
    for i in offers:
        name=i.text
        Offer.append(name)
    print(Offer)
# Out:
# ['85% off', '84% off', '82% off', '84% off', '65% off', '84% off', '66% off', '76% off', '74% off', '84% off', '74% off', '55% off', '72% off', '86% off', '79% off', '79% off', '69% off', '63% off', '69% off', '69% off', '68% off', '80% off', '72% off', '75% off', '80% off', '74% off', '66% off', '74% off', '86% off', '84% off', '41% off', '66% off', '70% off', '80% off', '80% off', '76% off', '66% off', '68% off', '19% off', '67% off', '41% off', '84% off', '74% off', '80% off', '75% off']
# ['84% off', '66% off', '70% off', '87% off', '67% off', '79% off', '76% off', '52% off', '74% off', '70% off', '74% off', '55% off', '71% off', '71% off', '70% off', '88% off', '68% off', '63% off', '83% off', '48% off', '69% off', '41% off', '86% off', '70% off', '71% off', '65% off', '80% off', '66% off', '61% off', '70% off', '74% off', '66% off', '76% off', '87% off', '69% off', '65% off', '66% off', '68% off', '72% off', '88% off', '41% off', '79% off', '84% off', '70% off', '87% off']
# ...

# %%
df = pd.DataFrame({
    "name": Product_Name,
    "Brd_name": Brand_name,
    "prices": Prices,
    "price": Original_Price,
    "offers": Offer 
})

# Print the DataFrame
print(df)
